# %% [raw]
# from google.colab import files
#
# uploaded = files.upload()  # Aparece un botón para subir imágenes

# %% [markdown]
# Ningún archivo seleccionado Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.
# Saving image7.jpeg to image7.jpeg
# Saving image8.jpeg to image8.jpeg
# Saving image9.jpeg to image9.jpeg

# %%
imagenes_memoria = []

for filename, filecontent in uploaded.items():
    imagenes_memoria.append({
        "filename": filename,
        "content": filecontent  # Es un objeto bytes listo para enviar
    })

print(f"Total imágenes t5rrsubidas: {len(imagenes_memoria)}")

# %% [markdown]
# Total imágenes subidas: 3

# %%
from PIL import Image
import io

imagenes_memoria_png = []

for img in imagenes_memoria:
    try:
        pil_img = Image.open(io.BytesIO(img["content"])).convert("RGB")
        buffer = io.BytesIO()
        pil_img.save(buffer, format="PNG")
        buffer.seek(0)
        imagenes_memoria_png.append({
            "filename": img["filename"] + ".png" if not img["filename"].endswith(".png") else img["filename"],
            "content": buffer.read()
        })
        print(f"{img['filename']} convertida a PNG y lista para subir.")
    except Exception as e:
        print(f"Error normalizando {img['filename']}: {e}")

# %% [markdown]
# image7 (1).jpeg convertida a PNG y lista para subir.
# image8 (1).jpeg convertida a PNG y lista para subir.
# image9 (1).jpeg convertida a PNG y lista para subir.

# %%
import requests

# Parámetros de tu endpoint
upload_url = "https://genboxaws-test.alttest.es/api/v1/llm/assistant/69af7f7a-ebe4-484e-aec6-3d2d23a331f3/files/upload?company_id=51b06062-f167-41de-a250-563722ab674e"
api_key = ""  # <-- pon aquí tu api key real

ids_archivos = []
headers = {
    'X-API-KEY': api_key
 }

for img in imagenes_memoria:
    files = {
        'file': (img["filename"], img["content"])  # El campo se llama "file"ºre
    }
    resp = requests.post(upload_url, files=files, headers=headers)
    try:
        resp_json = resp.json()
        file_id = resp_json.get("id")
        print(f"{img['filename']} subida. id = {file_id}")
        ids_archivos.append({
            "filename": img["filename"],
            "id": file_id
        })
    except Exception as e:
        print(f"Error subiendo {img['filename']}: {e} (resp={resp.text})")

# %% [markdown]
# image7.jpeg subida. id = 0197a64b-fecb-791b-9a5f-f37419dc3481
# image8.jpeg subida. id = 0197a64c-02f1-7bc5-a398-6f4588ca780c
# image9.jpeg subida. id = 0197a64c-071d-77de-8965-15682ddbc049

# %%
import base64
import requests
import uuid
import json


picture_agent = "https://genboxaws-test.alttest.es/api/v1/llm/assistant/69af7f7a-ebe4-484e-aec6-3d2d23a331f3/bot?company_id=51b06062-f167-41de-a250-563722ab674e"
picture_agent_key = "uQpHpcjFO1N7iD6nNLD02YQYYnpIpr8m"
picture_session_id = str(uuid.uuid4())


# 2. Prepara los mensajes tipo blob (imágenes)
messages = [
    {
        "type": "text",
        "text": "Hola, analiza el estado del coche en estas fotos."
    }
]

for archivo in ids_archivos:
    messages.append({
        "type": "file",
        "id": archivo["id"],
        "mime_type": "image/jpeg"

    })

# 3. Construye el JSON final
payload = {
    "chat_session_id": picture_session_id,
    "messages": messages
}

# Solo muestra la estructura, omitiendo el base64 real
#payload_preview = {
#    **{k: v for k, v in payload.items() if k != "messages"},
#    "messages": [
#        {**{k: (v if k != "data" else "[base64 omitido]") for k, v in m.items()}} for m in payload["messages"]
#    ]
#}

#print(json.dumps(payload_preview, indent=2))


headers = {
    'Content-Type': 'application/json',
    'X-API-KEY': picture_agent_key
 }

# 4. Haz la petición a la API
response = requests.post(picture_agent, headers=headers, data=json.dumps(payload))
try:
   result = response.json()
except Exception:
     result = response.text

respuesta = []
print(result['answer'])
respuesta.append(result['answer'])

# %% [markdown]
# ['\n\nIdentificación del vehículo:\nEl vehículo en las imágenes es un Toyota RAV4 Plug-in Hybrid, de color plata, con matrícula 3547 MLX.\n\nAnálisis detallado por secciones:\n\n1. Frente:\n   - Parachoques: Sin daños visibles. Alineación correcta.\n   - Capó: Sin abolladuras o arañazos aparentes. Pintura en excelente estado.\n   - Faros: Limpios y sin daños. Alineación correcta.\n   - Parrilla: Intacta y bien ajustada.\n   - Emblema de Toyota: Correctamente colocado y sin daños.\n\n2. Parte trasera:\n   - Portón trasero: Sin daños visibles. Alineación correcta.\n   - Parachoques trasero: En buen estado, sin arañazos o abolladuras visibles.\n   - Luces traseras: Intactas y limpias.\n   - Emblema y letras: Correctamente colocados y sin daños.\n\n3. Lateral (parcialmente visible):\n   - Puertas: Sin daños aparentes en las áreas visibles.\n   - Pintura: Uniforme y brillante, sin desgaste visible.\n\n4. Techo:\n   - Sin daños visibles en la parte observable.\n\n5. Ruedas y neumáticos:\n   - No visibles en las imágenes proporcionadas.\n\nEvaluación de la gravedad de los daños:\nNo se observan daños significativos en las áreas visibles del vehículo. Calificación general: 1/5 (excelente condición, sin daños aparentes).\n\nResumen general del estado del vehículo:\nEl Toyota RAV4 Plug-in Hybrid se encuentra en excelente estado general. La carrocería está intacta, sin signos visibles de golpes, arañazos o abolladuras. La pintura plateada mantiene un brillo uniforme en todas las áreas visibles, sugiriendo un cuidado meticuloso o posiblemente un vehículo muy nuevo. Todos los componentes externos como faros, parrilla, emblemas y luces traseras están en perfecto estado y correctamente alineados. No se observan signos de reparaciones previas o modificaciones en las áreas visibles.\n\nLimitaciones del análisis:\n- Las imágenes proporcionadas muestran principalmente el frente y la parte trasera del vehículo, con una vista parcial de un lateral.\n- No se pueden evaluar completamente los laterales del vehículo, el techo en su totalidad, ni las ruedas y neumáticos.\n- La iluminación del garaje puede ocultar imperfecciones menores en la pintura.\n- No es posible evaluar el estado mecánico o el interior del vehículo basándose únicamente en estas imágenes exteriores.\n\n']

# %%
from google.colab import files

ficha_uploaded = files.upload()  # Aparece un botón para subir imágenes

# %% [markdown]
# Ningún archivo seleccionado Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.
# Saving escaner_250612_101616-1.png to escaner_250612_101616-1 (2).png

# %%
ficha_tecnica = []

for filename, filecontent in ficha_uploaded.items():
    ficha_tecnica.append({
        "filename": filename,
        "content": filecontent  # Es un objeto bytes listo para enviar
    })

print(f"Ficha tecnica: {len(ficha_tecnica)}")

# %% [markdown]
# Ficha tecnica: 1

# %%
import requests

# Parámetros de tu endpoint
ficha_upload_url = "https://genboxaws-test.alttest.es/api/v1/llm/assistant/043aefb3-4e69-45bf-b80e-ee863bbdf1ea/files/upload?company_id=51b06062-f167-41de-a250-563722ab674e"
ficha_api_key = ""  # <-- pon aquí tu api key real

ficha_ids = []
headers = {
    'X-API-KEY': ficha_api_key
 }

for img in ficha_tecnica:
    files = {
        'file': (img["filename"], img["content"])  # El campo se llama "file"
    }
    resp = requests.post(ficha_upload_url, files=files, headers=headers)
    try:
        resp_json = resp.json()
        file_id = resp_json.get("id")
        print(f"{img['filename']} subida. id = {file_id}")
        ficha_ids.append({
            "filename": img["filename"],
            "id": file_id
        })
    except Exception as e:
        print(f"Error subiendo {img['filename']}: {e} (resp={resp.text})")

# %% [markdown]
# escaner_250612_101616-1 (2).png subida. id = 0197a666-0fbd-79b3-b56b-697404049d5d

# %%
ficha_agent = "https://genboxaws-test.alttest.es/api/v1/llm/assistant/043aefb3-4e69-45bf-b80e-ee863bbdf1ea/bot?company_id=51b06062-f167-41de-a250-563722ab674e"
ficha_agent_key = ""
ficha_session_id = str(uuid.uuid4())


# 2. Prepara los mensajes tipo blob (imágenes)
ficha_messages = [
    {
        "type": "text",
        "text": "Hola, analiza esta ficha técnica."
    }
]

for id in ficha_ids:
    ficha_messages.append({
        "type": "file",
        "id": id["id"]
    })

# 3. Construye el JSON final
payload = {
    "chat_session_id": ficha_session_id,
    "messages": ficha_messages
}



headers = {
    'Content-Type': 'application/json',
    'X-API-KEY': ficha_agent_key
 }

# 4. Haz la petición a la API
response = requests.post(ficha_agent, headers=headers, data=json.dumps(payload))
try:
   result = response.json()
except Exception:
     result = response.text

print(result['answer'])
respuesta.append(result['answer'])

# %% [markdown]
# Marca y Modelo: Toyota RAV4
#
# Número de homologación europea del vehículo (B): e016681039
# Número del certificado de conformidad o inspección técnica (Certificado Nº): D163375
# Matrícula española del vehículo (Matrícula): 3547MLX
# Nombre, dirección y país del titular del vehículo (C.1.1 / C.1.2 / C.1.3): TOYE0463H, TOYOTA MOTOR EUROPE NV/SA, AVENUE DU BOURGET 60 BOURGETLAAN 60 1140 BRUSSELS
# Marca del vehículo (D.1): TOYOTA
# Tipo del vehículo según el fabricante (D.2): XASP(EU,M) / AXAP5(4N) / AXAP5AL-ANXMBWY(1C)
# Variante y versión comercial del vehículo (D.3): TOYOTA RAV4
# Número de bastidor o VIN (identificación única del vehículo) (E): JTMGBRFXVD0163375
# Masa máxima técnicamente admisible (peso máximo autorizado) (F.1): 2510 kg
# Masa máxima autorizada en carga del vehículo (F.1.1): 1265 / 1315 kg
# Masa máxima autorizada del conjunto (vehículo + remolque) (F.1.5): 70 kg
# Masa en vacío del vehículo (sin carga ni ocupantes) (F.2): 2510 kg
# Categoría del vehículo según clasificación europea (J): M1
# Tipo de tracción (ejes motrices y disposición) (L.0): 2 / 4
# Cilindrada del motor en centímetros cúbicos (P.3.1): 4010 cc
# Potencia máxima neta del motor (en kW) (P.1.1): 1500 kW
# Régimen del motor al que se alcanza la potencia máxima (en rpm) (P.1.3): 1500 rpm
# Tipo de combustible o fuente de energía (P.3): M / G / 166 / PHEV / 75
# Número de plazas disponibles para pasajeros, incluido el conductor (S.1): 5
# Emisiones de CO₂ (en g/km) (V.7): 22 g/km
# Norma de emisiones (V.9): EURO 6AP
# Dimensiones homologadas para los neumáticos (Neumáticos): 225/60R18 100H 18x7J ET35 C1 B
# Equipamiento adicional homologado (Opciones incluidas): CRISTALES TRASEROS OSCURECIDOS, BARRAS LONGITUDINALES DE TECHO
# Fecha de emisión del documento técnico (Fecha de emisión): 17/11/2023
# Información adicional (Observaciones): Masa Real:02015 Potencia Nominal Motor 1: 134 Potencia Nominal Motor 3: 40 VEHICULO IMPORTADO CON DUA N. 23E500359138274664 CON FECHA 13/11/2023 DE LA ADUANA DE LAS PALMAS
#
# ['\n\nIdentificación del vehículo:\nEl vehículo en las imágenes es un Toyota RAV4 Plug-in Hybrid, de color plata, con matrícula 3547 MLX.\n\nAnálisis detallado por secciones:\n\n1. Frente:\n   - Parachoques: Sin daños visibles. Alineación correcta.\n   - Capó: Sin abolladuras o arañazos aparentes. Pintura en excelente estado.\n   - Faros: Limpios y sin daños. Alineación correcta.\n   - Parrilla: Intacta y bien ajustada.\n   - Emblema de Toyota: Correctamente colocado y sin daños.\n\n2. Parte trasera:\n   - Portón trasero: Sin daños visibles. Alineación correcta.\n   - Parachoques trasero: En buen estado, sin arañazos o abolladuras visibles.\n   - Luces traseras: Intactas y limpias.\n   - Emblema y letras: Correctamente colocados y sin daños.\n\n3. Lateral (parcialmente visible):\n   - Puertas: Sin daños aparentes en las áreas visibles.\n   - Pintura: Uniforme y brillante, sin desgaste visible.\n\n4. Techo:\n   - Sin daños visibles en la parte observable.\n\n5. Ruedas y neumáticos:\n   - No visibles en las imágenes proporcionadas.\n\nEvaluación de la gravedad de los daños:\nNo se observan daños significativos en las áreas visibles del vehículo. Calificación general: 1/5 (excelente condición, sin daños aparentes).\n\nResumen general del estado del vehículo:\nEl Toyota RAV4 Plug-in Hybrid se encuentra en excelente estado general. La carrocería está intacta, sin signos visibles de golpes, arañazos o abolladuras. La pintura plateada mantiene un brillo uniforme en todas las áreas visibles, sugiriendo un cuidado meticuloso o posiblemente un vehículo muy nuevo. Todos los componentes externos como faros, parrilla, emblemas y luces traseras están en perfecto estado y correctamente alineados. No se observan signos de reparaciones previas o modificaciones en las áreas visibles.\n\nLimitaciones del análisis:\n- Las imágenes proporcionadas muestran principalmente el frente y la parte trasera del vehículo, con una vista parcial de un lateral.\n- No se pueden evaluar completamente los laterales del vehículo, el techo en su totalidad, ni las ruedas y neumáticos.\n- La iluminación del garaje puede ocultar imperfecciones menores en la pintura.\n- No es posible evaluar el estado mecánico o el interior del vehículo basándose únicamente en estas imágenes exteriores.\n\n', '\n\nMarca y Modelo: Toyota Aygo X\n\nEspecificaciones técnicas extraídas de la ficha:\n\n1. Información de identificación:\n- Número de homologación (B): e01*2007/46*0163*75\n- Certificado Nº: D163375\n- Matrícula: 3547MLX\n\n2. Información del vehículo:\n- D.1 (Marca): TOYOTA\n- D.2 (Tipo): KGB10\n- D.2.1 / D.3 (Variante/Versión): PA10 / 1315 /-----\n\n3. Características técnicas:\n- E (Número de bastidor): JTDKGNEC600163375\n- F.1 (Masa máxima técnicamente admisible): 1360 kg\n- G (Masa en vacío): 1005 kg\n- P.1 (Cilindrada): 998 cm³\n- P.2 (Potencia máxima neta): 53 kW\n- P.3 (Tipo de combustible): GASOLINA\n- S.1 (Número de plazas): 4\n- V.7 (Emisiones de CO₂): 122 g/km\n- V.9 (Norma de emisiones): EURO 6AP\n\n4. Dimensiones:\n- L.0 (Número de ejes): 2\n- M.1 (Distancia entre ejes): 2430 mm\n\n5. Información adicional:\n- J (Categoría del vehículo): M1\n- K (Número de homologación de tipo): e01*2007/46*0163*75\n- Q.1 (Relación potencia/peso para motocicletas): No aplicable\n- U.1 / U.2 / U.3 (Niveles sonoros): No disponible\n- O.1 (Masa máxima remolcable con freno): 750 kg\n- O.2 (Masa máxima remolcable sin freno): 550 kg\n\n6. Neumáticos:\n- Dimensiones homologadas: 175/65 R14 86H\n\n7. Opciones incluidas:\n- Cristales tintados\n- Barras longitudinales\n- Techo\n\n8. Fecha de emisión: 17/11/2023\n\nObservaciones:\n- Masa Residual Rodante Normal Motor 1: 134 (Volumen Normal Motor 1: 134)\n- DE LA ADUANA DE LAS PALMAS\n\nInformación adicional:\n- El vehículo cumple con la normativa europea de emisiones EURO 6AP.\n- La ficha técnica está emitida por TOYOTA ESPAÑA S.L.U.\n\n', '\n\nMarca y Modelo: Toyota 3547MLX\n\nEspecificaciones técnicas:\n\nB: e016681039 (Número de homologación europea)\n\nCertificado Nº: D163375\n\nMatrícula: 3547MLX\n\nD.1: TOYOTA (Marca)\nD.2: TCT69405H (Tipo según fabricante)\nD.2.1: 47 (Variante)\nD.3: AVENSIS (Versión comercial)\n\nE: JTMBT31V40D163375 (Número de bastidor/VIN)\n\nF.1: 2050 (Masa máxima técnicamente admisible en kg)\nF.2: 2050 (Masa máxima autorizada en carga en kg)\nG: 1495 (Masa en vacío en kg)\n\nJ: M1 (Categoría del vehículo)\n\nP.1: 1987 (Cilindrada en cm³)\nP.2: 100 (Potencia máxima neta en kW)\nP.3: GASOLINA (Tipo de combustible)\n\nS.1: 5 (Número de plazas)\n\nV.7: 156 (Emisiones de CO₂ en g/km)\nV.9: EURO 6AP (Norma de emisiones)\n\nNeumáticos: 225/60R18 100H 1807, ET35 C1 B\n\nFecha de emisión: 17/11/2023\n\nObservaciones: \n- Masa Referencia: 1641 kg\n- Volumen Normal Motor: 1,987 l\n- 134 Volumen Nominal Motor: 1,987 l\n\nOpciones incluidas en la homologación de tipo:\n- CRISTALES TRASEROS OSCURECIDOS, BARRAS LONGITUDINALES\n- TECHO\n\nInformación adicional:\n- El vehículo parece ser un Toyota Avensis, basado en la información de la versión comercial.\n- La potencia del motor es de 100 kW, que equivale aproximadamente a 134 CV.\n- El vehículo tiene una configuración de 5 plazas.\n- Cumple con la norma de emisiones Euro 6AP.\n- Los neumáticos homologados son 225/60R18 100H.\n\n', '\nMarca y Modelo: Toyota Corolla\n\nDatos extraídos:\n- Número de homologación europea del vehículo (B): e016681039\n- Número del certificado de conformidad o inspección técnica (Certificado Nº): 3547MLX\n- Matrícula española del vehículo (Matrícula): Información no disponible\n- Nombre, dirección y país del titular del vehículo (C.1.1 / C.1.2 / C.1.3): Información no disponible\n- Marca del vehículo (D.1): Toyota\n- Tipo del vehículo según el fabricante (D.2): Corolla\n- Variante y versión comercial del vehículo (D.2.1 / D.3): Información no disponible\n- Número de bastidor o VIN (identificación única del vehículo) (E): JTMGBFXV0D63375\n- Masa máxima técnicamente admisible (peso máximo autorizado) (F.1): 1500 kg\n- Masa máxima autorizada en carga del vehículo (F.2): 750 kg\n- Masa máxima autorizada del conjunto (vehículo + remolque) (F.3): 1640 kg\n- Masa en vacío del vehículo (sin carga ni ocupantes) (G): 1000 kg\n- Categoría del vehículo según clasificación europea (J / J.1 / J.2): M1\n- Tipo de tracción (ejes motrices y disposición) (L.0): Tracción delantera\n- Cilindrada del motor en centímetros cúbicos (P.1): 1798 cc\n- Potencia máxima neta del motor (en kW) (P.2): 103 kW\n- Régimen del motor al que se alcanza la potencia máxima (en rpm) (P.2.1): 6000 rpm\n- Tipo de combustible o fuente de energía (P.3): Gasolina\n- Número de plazas disponibles para pasajeros, incluido el conductor (S.1): 5\n- Número de plazas de pie (aplicable a vehículos de transporte colectivo) (S.2): Información no disponible\n- Niveles sonoros (U.1 / U.2 / U.3): Información no disponible\n- Emisiones de CO₂ (en g/km) (V.7): 164 g/km\n- Norma de emisiones (V.9): Euro 6\n- Masa máxima remolcable con freno (O.1): 1500 kg\n- Masa máxima remolcable sin freno (O.2): 750 kg\n- Dimensiones homologadas para los neumáticos (Neumáticos): 205/60 R16\n- Equipamiento adicional homologado (Opciones incluidas): Información no disponible\n- Fecha de emisión del documento técnico (Fecha de emisión): 17/11/2023\n- Información adicional como importación, aduanas, etc. (Observaciones): Información no disponible\n', '\nMarca y Modelo: Toyota RAV4\n\nNúmero de homologación europea del vehículo (B): e016681039\nNúmero del certificado de conformidad o inspección técnica (Certificado Nº): D163375\nMatrícula española del vehículo (Matrícula): 3547MLX\nNombre, dirección y país del titular del vehículo (C.1.1 / C.1.2 / C.1.3): TOYE0463H, TOYOTA MOTOR EUROPE NV/SA, AVENUE DU BOURGET 60 BOURGETLAAN 60 1140 BRUSSELS\nMarca del vehículo (D.1): TOYOTA\nTipo del vehículo según el fabricante (D.2): XASP(EU,M) / AXAP5(4N) / AXAP5AL-ANXMBWY(1C)\nVariante y versión comercial del vehículo (D.3): TOYOTA RAV4\nNúmero de bastidor o VIN (identificación única del vehículo) (E): JTMGBRFXVD0163375\nMasa máxima técnicamente admisible (peso máximo autorizado) (F.1): 2510 kg\nMasa máxima autorizada en carga del vehículo (F.1.1): 1265 / 1315 kg\nMasa máxima autorizada del conjunto (vehículo + remolque) (F.1.5): 70 kg\nMasa en vacío del vehículo (sin carga ni ocupantes) (F.2): 2510 kg\nCategoría del vehículo según clasificación europea (J): M1\nTipo de tracción (ejes motrices y disposición) (L.0): 2 / 4\nCilindrada del motor en centímetros cúbicos (P.3.1): 4010 cc\nPotencia máxima neta del motor (en kW) (P.1.1): 1500 kW\nRégimen del motor al que se alcanza la potencia máxima (en rpm) (P.1.3): 1500 rpm\nTipo de combustible o fuente de energía (P.3): M / G / 166 / PHEV / 75\nNúmero de plazas disponibles para pasajeros, incluido el conductor (S.1): 5\nEmisiones de CO₂ (en g/km) (V.7): 22 g/km\nNorma de emisiones (V.9): EURO 6AP\nDimensiones homologadas para los neumáticos (Neumáticos): 225/60R18 100H 18x7J ET35 C1 B\nEquipamiento adicional homologado (Opciones incluidas): CRISTALES TRASEROS OSCURECIDOS, BARRAS LONGITUDINALES DE TECHO\nFecha de emisión del documento técnico (Fecha de emisión): 17/11/2023\nInformación adicional (Observaciones): Masa Real:02015 Potencia Nominal Motor 1: 134 Potencia Nominal Motor 3: 40 VEHICULO IMPORTADO CON DUA N. 23E500359138274664 CON FECHA 13/11/2023 DE LA ADUANA DE LAS PALMAS\n']

# %%
final_agent = "https://genboxaws-test.alttest.es/api/v1/llm/assistant/0a210643-2b71-4883-bf60-92154e7b8e70/bot?company_id=51b06062-f167-41de-a250-563722ab674e"
final_agent_key = ""
final_session_id = str(uuid.uuid4())


# Si respuesta es una lista de strings
if isinstance(respuesta, list):
    texto_final = "\n".join(respuesta)
else:
    texto_final = str(respuesta)

final_messages = [
    {
        "type": "text",
        "text": texto_final
    }
]

# 3. Construye el JSON final
payload = {
    "chat_session_id": final_session_id,
    "messages": final_messages
}


#print(json.dumps(payload_preview, indent=2))


headers = {
    'Content-Type': 'application/json',
    'X-API-KEY': final_agent_key
 }

# 4. Haz la petición a la API
response = requests.post(final_agent, headers=headers, data=json.dumps(payload))
try:
   result = response.json()
except Exception:
     result = response.text

print(result['answer'])

# %% [markdown]
# [{'type': 'text', 'text': '\n\nIdentificación del vehículo:\nEl vehículo en las imágenes es un Toyota RAV4 Plug-in Hybrid, de color plata, con matrícula 3547 MLX.\n\nAnálisis detallado por secciones:\n\n1. Frente:\n   - Parachoques: Sin daños visibles. Alineación correcta.\n   - Capó: Sin abolladuras o arañazos aparentes. Pintura en excelente estado.\n   - Faros: Limpios y sin daños. Alineación correcta.\n   - Parrilla: Intacta y bien ajustada.\n   - Emblema de Toyota: Correctamente colocado y sin daños.\n\n2. Parte trasera:\n   - Portón trasero: Sin daños visibles. Alineación correcta.\n   - Parachoques trasero: En buen estado, sin arañazos o abolladuras visibles.\n   - Luces traseras: Intactas y limpias.\n   - Emblema y letras: Correctamente colocados y sin daños.\n\n3. Lateral (parcialmente visible):\n   - Puertas: Sin daños aparentes en las áreas visibles.\n   - Pintura: Uniforme y brillante, sin desgaste visible.\n\n4. Techo:\n   - Sin daños visibles en la parte observable.\n\n5. Ruedas y neumáticos:\n   - No visibles en las imágenes proporcionadas.\n\nEvaluación de la gravedad de los daños:\nNo se observan daños significativos en las áreas visibles del vehículo. Calificación general: 1/5 (excelente condición, sin daños aparentes).\n\nResumen general del estado del vehículo:\nEl Toyota RAV4 Plug-in Hybrid se encuentra en excelente estado general. La carrocería está intacta, sin signos visibles de golpes, arañazos o abolladuras. La pintura plateada mantiene un brillo uniforme en todas las áreas visibles, sugiriendo un cuidado meticuloso o posiblemente un vehículo muy nuevo. Todos los componentes externos como faros, parrilla, emblemas y luces traseras están en perfecto estado y correctamente alineados. No se observan signos de reparaciones previas o modificaciones en las áreas visibles.\n\nLimitaciones del análisis:\n- Las imágenes proporcionadas muestran principalmente el frente y la parte trasera del vehículo, con una vista parcial de un lateral.\n- No se pueden evaluar completamente los laterales del vehículo, el techo en su totalidad, ni las ruedas y neumáticos.\n- La iluminación del garaje puede ocultar imperfecciones menores en la pintura.\n- No es posible evaluar el estado mecánico o el interior del vehículo basándose únicamente en estas imágenes exteriores.\n\n\n\n\nMarca y Modelo: Toyota Aygo X\n\nEspecificaciones técnicas extraídas de la ficha:\n\n1. Información de identificación:\n- Número de homologación (B): e01*2007/46*0163*75\n- Certificado Nº: D163375\n- Matrícula: 3547MLX\n\n2. Información del vehículo:\n- D.1 (Marca): TOYOTA\n- D.2 (Tipo): KGB10\n- D.2.1 / D.3 (Variante/Versión): PA10 / 1315 /-----\n\n3. Características técnicas:\n- E (Número de bastidor): JTDKGNEC600163375\n- F.1 (Masa máxima técnicamente admisible): 1360 kg\n- G (Masa en vacío): 1005 kg\n- P.1 (Cilindrada): 998 cm³\n- P.2 (Potencia máxima neta): 53 kW\n- P.3 (Tipo de combustible): GASOLINA\n- S.1 (Número de plazas): 4\n- V.7 (Emisiones de CO₂): 122 g/km\n- V.9 (Norma de emisiones): EURO 6AP\n\n4. Dimensiones:\n- L.0 (Número de ejes): 2\n- M.1 (Distancia entre ejes): 2430 mm\n\n5. Información adicional:\n- J (Categoría del vehículo): M1\n- K (Número de homologación de tipo): e01*2007/46*0163*75\n- Q.1 (Relación potencia/peso para motocicletas): No aplicable\n- U.1 / U.2 / U.3 (Niveles sonoros): No disponible\n- O.1 (Masa máxima remolcable con freno): 750 kg\n- O.2 (Masa máxima remolcable sin freno): 550 kg\n\n6. Neumáticos:\n- Dimensiones homologadas: 175/65 R14 86H\n\n7. Opciones incluidas:\n- Cristales tintados\n- Barras longitudinales\n- Techo\n\n8. Fecha de emisión: 17/11/2023\n\nObservaciones:\n- Masa Residual Rodante Normal Motor 1: 134 (Volumen Normal Motor 1: 134)\n- DE LA ADUANA DE LAS PALMAS\n\nInformación adicional:\n- El vehículo cumple con la normativa europea de emisiones EURO 6AP.\n- La ficha técnica está emitida por TOYOTA ESPAÑA S.L.U.\n\n\n\n\nMarca y Modelo: Toyota 3547MLX\n\nEspecificaciones técnicas:\n\nB: e016681039 (Número de homologación europea)\n\nCertificado Nº: D163375\n\nMatrícula: 3547MLX\n\nD.1: TOYOTA (Marca)\nD.2: TCT69405H (Tipo según fabricante)\nD.2.1: 47 (Variante)\nD.3: AVENSIS (Versión comercial)\n\nE: JTMBT31V40D163375 (Número de bastidor/VIN)\n\nF.1: 2050 (Masa máxima técnicamente admisible en kg)\nF.2: 2050 (Masa máxima autorizada en carga en kg)\nG: 1495 (Masa en vacío en kg)\n\nJ: M1 (Categoría del vehículo)\n\nP.1: 1987 (Cilindrada en cm³)\nP.2: 100 (Potencia máxima neta en kW)\nP.3: GASOLINA (Tipo de combustible)\n\nS.1: 5 (Número de plazas)\n\nV.7: 156 (Emisiones de CO₂ en g/km)\nV.9: EURO 6AP (Norma de emisiones)\n\nNeumáticos: 225/60R18 100H 1807, ET35 C1 B\n\nFecha de emisión: 17/11/2023\n\nObservaciones: \n- Masa Referencia: 1641 kg\n- Volumen Normal Motor: 1,987 l\n- 134 Volumen Nominal Motor: 1,987 l\n\nOpciones incluidas en la homologación de tipo:\n- CRISTALES TRASEROS OSCURECIDOS, BARRAS LONGITUDINALES\n- TECHO\n\nInformación adicional:\n- El vehículo parece ser un Toyota Avensis, basado en la información de la versión comercial.\n- La potencia del motor es de 100 kW, que equivale aproximadamente a 134 CV.\n- El vehículo tiene una configuración de 5 plazas.\n- Cumple con la norma de emisiones Euro 6AP.\n- Los neumáticos homologados son 225/60R18 100H.\n\n\n\nMarca y Modelo: Toyota Corolla\n\nDatos extraídos:\n- Número de homologación europea del vehículo (B): e016681039\n- Número del certificado de conformidad o inspección técnica (Certificado Nº): 3547MLX\n- Matrícula española del vehículo (Matrícula): Información no disponible\n- Nombre, dirección y país del titular del vehículo (C.1.1 / C.1.2 / C.1.3): Información no disponible\n- Marca del vehículo (D.1): Toyota\n- Tipo del vehículo según el fabricante (D.2): Corolla\n- Variante y versión comercial del vehículo (D.2.1 / D.3): Información no disponible\n- Número de bastidor o VIN (identificación única del vehículo) (E): JTMGBFXV0D63375\n- Masa máxima técnicamente admisible (peso máximo autorizado) (F.1): 1500 kg\n- Masa máxima autorizada en carga del vehículo (F.2): 750 kg\n- Masa máxima autorizada del conjunto (vehículo + remolque) (F.3): 1640 kg\n- Masa en vacío del vehículo (sin carga ni ocupantes) (G): 1000 kg\n- Categoría del vehículo según clasificación europea (J / J.1 / J.2): M1\n- Tipo de tracción (ejes motrices y disposición) (L.0): Tracción delantera\n- Cilindrada del motor en centímetros cúbicos (P.1): 1798 cc\n- Potencia máxima neta del motor (en kW) (P.2): 103 kW\n- Régimen del motor al que se alcanza la potencia máxima (en rpm) (P.2.1): 6000 rpm\n- Tipo de combustible o fuente de energía (P.3): Gasolina\n- Número de plazas disponibles para pasajeros, incluido el conductor (S.1): 5\n- Número de plazas de pie (aplicable a vehículos de transporte colectivo) (S.2): Información no disponible\n- Niveles sonoros (U.1 / U.2 / U.3): Información no disponible\n- Emisiones de CO₂ (en g/km) (V.7): 164 g/km\n- Norma de emisiones (V.9): Euro 6\n- Masa máxima remolcable con freno (O.1): 1500 kg\n- Masa máxima remolcable sin freno (O.2): 750 kg\n- Dimensiones homologadas para los neumáticos (Neumáticos): 205/60 R16\n- Equipamiento adicional homologado (Opciones incluidas): Información no disponible\n- Fecha de emisión del documento técnico (Fecha de emisión): 17/11/2023\n- Información adicional como importación, aduanas, etc. (Observaciones): Información no disponible\n\n\nMarca y Modelo: Toyota RAV4\n\nNúmero de homologación europea del vehículo (B): e016681039\nNúmero del certificado de conformidad o inspección técnica (Certificado Nº): D163375\nMatrícula española del vehículo (Matrícula): 3547MLX\nNombre, dirección y país del titular del vehículo (C.1.1 / C.1.2 / C.1.3): TOYE0463H, TOYOTA MOTOR EUROPE NV/SA, AVENUE DU BOURGET 60 BOURGETLAAN 60 1140 BRUSSELS\nMarca del vehículo (D.1): TOYOTA\nTipo del vehículo según el fabricante (D.2): XASP(EU,M) / AXAP5(4N) / AXAP5AL-ANXMBWY(1C)\nVariante y versión comercial del vehículo (D.3): TOYOTA RAV4\nNúmero de bastidor o VIN (identificación única del vehículo) (E): JTMGBRFXVD0163375\nMasa máxima técnicamente admisible (peso máximo autorizado) (F.1): 2510 kg\nMasa máxima autorizada en carga del vehículo (F.1.1): 1265 / 1315 kg\nMasa máxima autorizada del conjunto (vehículo + remolque) (F.1.5): 70 kg\nMasa en vacío del vehículo (sin carga ni ocupantes) (F.2): 2510 kg\nCategoría del vehículo según clasificación europea (J): M1\nTipo de tracción (ejes motrices y disposición) (L.0): 2 / 4\nCilindrada del motor en centímetros cúbicos (P.3.1): 4010 cc\nPotencia máxima neta del motor (en kW) (P.1.1): 1500 kW\nRégimen del motor al que se alcanza la potencia máxima (en rpm) (P.1.3): 1500 rpm\nTipo de combustible o fuente de energía (P.3): M / G / 166 / PHEV / 75\nNúmero de plazas disponibles para pasajeros, incluido el conductor (S.1): 5\nEmisiones de CO₂ (en g/km) (V.7): 22 g/km\nNorma de emisiones (V.9): EURO 6AP\nDimensiones homologadas para los neumáticos (Neumáticos): 225/60R18 100H 18x7J ET35 C1 B\nEquipamiento adicional homologado (Opciones incluidas): CRISTALES TRASEROS OSCURECIDOS, BARRAS LONGITUDINALES DE TECHO\nFecha de emisión del documento técnico (Fecha de emisión): 17/11/2023\nInformación adicional (Observaciones): Masa Real:02015 Potencia Nominal Motor 1: 134 Potencia Nominal Motor 3: 40 VEHICULO IMPORTADO CON DUA N. 23E500359138274664 CON FECHA 13/11/2023 DE LA ADUANA DE LAS PALMAS\n'}]
#
#
# Informe de Evaluación del Vehículo:
#
# 1. Estado Estético:
#    - Pintura: Excelente estado, color plata uniforme y brillante
#    - Carrocería: Sin daños visibles, abolladuras o arañazos
#    - Exteriores: Parachoques, capó, faros, parrilla y emblemas en perfecto estado
#    - Interiores: No evaluables con la información proporcionada
#
# 2. Ficha Técnica:
#    - Modelo: Toyota RAV4 Plug-in Hybrid
#    - Año: 2023 (estimado basado en la fecha de emisión del documento)
#    - VIN: JTMGBRFXVD0163375
#    - Motor: 4010 cc
#    - Potencia: 1500 kW
#    - Transmisión: No especificada, probablemente automática
#    - Tipo de combustible: PHEV (Híbrido Enchufable)
#    - Emisiones CO₂: 22 g/km
#    - Norma de emisiones: EURO 6AP
#    - Peso máximo autorizado: 2510 kg
#    - Peso en vacío: 2015 kg
#    - Plazas: 5
#    - Neumáticos: 225/60R18 100H
#
# 3. Información Completada:
#    - Kilometraje: No especificado, pero dado el excelente estado, se estima bajo
#    - Extras: Cristales traseros oscurecidos, barras longitudinales de techo
#    - Estado del motor: Se presume excelente dado el estado general del vehículo
#    - Condición mecánica: Se estima óptima, aunque se recomienda una inspección detallada
#
# 4. Evaluación General:
#    El Toyota RAV4 Plug-in Hybrid se encuentra en un estado excepcional, prácticamente como nuevo. Su condición estética es impecable, sin daños visibles en la carrocería o elementos exteriores. Las especificaciones técnicas indican un vehículo de alta gama con tecnología híbrida enchufable, lo que sugiere un rendimiento eficiente y respetuoso con el medio ambiente. La baja emisión de CO₂ (22 g/km) es particularmente destacable.
#
# 5. Recomendaciones:
#    - Realizar una inspección mecánica completa para verificar el estado del sistema híbrido y componentes eléctricos.
#    - Verificar el historial de mantenimiento y si aún está bajo garantía del fabricante.
#    - Comprobar el kilometraje real y compararlo con el promedio para este modelo y año.
#    - Realizar una prueba de conducción para evaluar el funcionamiento del sistema híbrido y la transmisión.
#    - Considerar el valor de mercado actual para este modelo, teniendo en cuenta su excelente estado y la tecnología híbrida enchufable.
#    - Verificar la disponibilidad de puntos de carga en su área para aprovechar al máximo la capacidad eléctrica del vehículo.
#
# En conclusión, este Toyota RAV4 Plug-in Hybrid parece ser una excelente opción para aquellos que buscan un SUV de alta gama, eficiente y en condiciones prácticamente nuevas. Su estado impecable y tecnología avanzada lo convierten en una opción muy atractiva en el mercado de vehículos híbridos enchufables.
